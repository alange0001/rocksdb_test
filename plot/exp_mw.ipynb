# %%
import plot
options = plot.Options(print_params=True, graphTickMajor=10, graphTickMinor=4)
#options.save=True

#plot.plotFiles([
#    'exp_mw/mw_per_threads_writeratio-dbs1_threads20.out',
#    'exp_mw/mw_per_threads_writeratio-dbs1_threads25.out',
#    'exp_mw/mw_per_threads_writeratio-dbs1_threads30.out',
#    ], options)
plot.plotFiles(plot.getFiles('exp_mw'), options)
# Out:
# ######################################################
# Graphs from file "exp_mw/mw_per_threads_writeratio-dbs1_threads10.out":
#
# Params:
# log_level           : info
# duration            : 61
# warm_period         : 1
# stats_interval      : 5
# num_dbs             : 1
# db_create           : false
# db_mixgraph_params  : --sine_a=1000 --sine_d=4500
# num_ydbs            : 0
# ydb_create          : false
# rocksdb_config_file :
# num_at              : 0
# io_device           : nvme0n1
# db_benchmark[0]     : mixedworkload
# db_path[0]          : /media/auto/work/rocksdb_1
# db_num_keys[0]      : 500000000
# db_num_levels[0]    : 6
# db_cache_size[0]    : 536870912
# db_threads[0]       : 10
# db_readwritepercent[0]: 90
# db_workloadscript[0]: writeratio=0.05;16m:writeratio=0.1;31m:writeratio=0.2;46m:writeratio=0.5
# db_sine_cycles[0]   : 1
# db_sine_shift[0]    : 0
# db_bench_params[0]  :
# ######################################################
# ...
