# %%
import plot
options = plot.Options(print_params=True, graphTickMajor=10, graphTickMinor=4)
#options.save=True

#plot.plotFiles(['exp_mw/dbbench_mw_dbs4_threads10_writeratio20.out'], options)
plot.plotFiles(plot.getFiles('exp_mw'), options)
# Out:
# ######################################################
# Graphs from file "exp_mw/dbbench_mw_dbs1_threads10_writeratio05.out":
#
# Params:
# log_level           : info
# duration            : 50
# warm_period         : 1
# stats_interval      : 5
# num_dbs             : 4
# db_create           : false
# db_mixgraph_params  : --sine_a=1000 --sine_d=4500
# num_ydbs            : 0
# ydb_create          : false
# rocksdb_config_file :
# num_at              : 0
# io_device           : nvme0n1
# db_benchmark[0]     : mixedworkload
# db_benchmark[1]     : mixedworkload
# db_benchmark[2]     : mixedworkload
# db_benchmark[3]     : mixedworkload
# db_path[0]          : /media/auto/work/rocksdb_1
# db_path[1]          : /media/auto/work/rocksdb_2
# db_path[2]          : /media/auto/work/rocksdb_3
# db_path[3]          : /media/auto/work/rocksdb_4
# db_num_keys[0]      : 500000000
# db_num_keys[1]      : 500000000
# db_num_keys[2]      : 500000000
# db_num_keys[3]      : 500000000
# ...
