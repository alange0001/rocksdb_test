# %%
import plot
options = plot.Options(print_params=True, graphTickMajor=10, graphTickMinor=4)
#options.save=True

#plot.plotFiles(['file.out'], options)

plot.plotFiles(plot.getFiles('exp_ycsb'), options)
# Out:
# ######################################################
# Graphs from file "exp_ycsb/ycsb_db1-threads4_workloada.out":
#
# Params:
# log_level           : info
# duration            : 31
# warm_period         : 1
# stats_interval      : 5
# num_dbs             : 0
# db_create           : false
# db_mixgraph_params  : --sine_a=1000 --sine_d=4500
# num_ydbs            : 1
# ydb_create          : false
# rocksdb_config_file :
# num_at              : 0
# io_device           : nvme0n1
# ydb_path[0]         : /media/auto/work/ycsb_1
# ydb_workload[0]     : /home/alange/workspace/dr/rocksdb_test/../YCSB/workloads/workloada
# ydb_num_keys[0]     : 50000000
# ydb_threads[0]      : 4
# ydb_params[0]       :
# ######################################################
# Graphs from file "exp_ycsb/ycsb_db1-threads4_workloadb.out":
#
# Params:
# log_level           : info
# duration            : 31
# warm_period         : 1
# stats_interval      : 5
# num_dbs             : 0
# db_create           : false
# db_mixgraph_params  : --sine_a=1000 --sine_d=4500
# num_ydbs            : 1
# ydb_create          : false
# rocksdb_config_file :
# num_at              : 0
# io_device           : nvme0n1
# ydb_path[0]         : /media/auto/work/ycsb_1
# ydb_workload[0]     : /home/alange/workspace/dr/rocksdb_test/../YCSB/workloads/workloadb
# ydb_num_keys[0]     : 50000000
# ydb_threads[0]      : 4
# ydb_params[0]       :
# ######################################################
# Graphs from file "exp_ycsb/ycsb_db1-threads6_workloada.out":
#
# Params:
# log_level           : info
# duration            : 31
# warm_period         : 1
# stats_interval      : 5
# num_dbs             : 0
# db_create           : false
# db_mixgraph_params  : --sine_a=1000 --sine_d=4500
# num_ydbs            : 1
# ydb_create          : false
# rocksdb_config_file :
# num_at              : 0
# io_device           : nvme0n1
# ydb_path[0]         : /media/auto/work/ycsb_1
# ydb_workload[0]     : /home/alange/workspace/dr/rocksdb_test/../YCSB/workloads/workloada
# ydb_num_keys[0]     : 50000000
# ydb_threads[0]      : 6
# ydb_params[0]       :
# ######################################################
# Graphs from file "exp_ycsb/ycsb_db1-threads6_workloadb.out":
#
# Params:
# log_level           : info
# duration            : 31
# warm_period         : 1
# stats_interval      : 5
# num_dbs             : 0
# db_create           : false
# db_mixgraph_params  : --sine_a=1000 --sine_d=4500
# num_ydbs            : 1
# ydb_create          : false
# rocksdb_config_file :
# num_at              : 0
# io_device           : nvme0n1
# ydb_path[0]         : /media/auto/work/ycsb_1
# ydb_workload[0]     : /home/alange/workspace/dr/rocksdb_test/../YCSB/workloads/workloadb
# ydb_num_keys[0]     : 50000000
# ydb_threads[0]      : 6
# ydb_params[0]       :
