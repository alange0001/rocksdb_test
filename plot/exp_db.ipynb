# %%
import plot
options = plot.Options(
    save=False,
    plot_nothing=True,
    plot_db=True,
    plot_pressure=True,
    print_params=False,
    db_mean_interval=2)
options.file_start_time['exp_db/ycsb_wa.out'] = 30
options.file_start_time['exp_db/ycsb_wb.out'] = 30
options.file_start_time['exp_db/dbbench_wwr.out'] = 30

# %% [markdown]
# ## YCSB Workload A

# %%
plot.plotFiles([
    'exp_db/ycsb_wa.out',
    'exp_db/ycsb_wa,at3_bs4_directio.out',
    'exp_db/ycsb_wa,at3_bs16_directio.out',
    'exp_db/ycsb_wa,at3_bs32_directio.out',
    'exp_db/ycsb_wa,at3_bs64_directio.out',
    'exp_db/ycsb_wa,at3_bs128_directio.out',
    'exp_db/ycsb_wa,at3_bs256_directio.out',
    'exp_db/ycsb_wa,at3_bs512_directio.out',
], options)
# Out:
# ######################################################
# Graphs from file "exp_db/ycsb_wa.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wa,at3_bs4_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wa,at3_bs16_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wa,at3_bs32_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wa,at3_bs64_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wa,at3_bs128_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wa,at3_bs256_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wa,at3_bs512_directio.out":

# %% [markdown]
# ## YCSB workload B

# %%
plot.plotFiles([
    'exp_db/ycsb_wb.out',
    'exp_db/ycsb_wb,at3_bs4_directio.out',
    'exp_db/ycsb_wb,at3_bs16_directio.out',
    'exp_db/ycsb_wb,at3_bs32_directio.out',
    'exp_db/ycsb_wb,at3_bs64_directio.out',
    'exp_db/ycsb_wb,at3_bs128_directio.out',
    'exp_db/ycsb_wb,at3_bs256_directio.out',
    'exp_db/ycsb_wb,at3_bs512_directio.out',
], options)
# Out:
# ######################################################
# Graphs from file "exp_db/ycsb_wb.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wb,at3_bs4_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wb,at3_bs16_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wb,at3_bs32_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wb,at3_bs64_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wb,at3_bs128_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wb,at3_bs256_directio.out":
# ######################################################
# Graphs from file "exp_db/ycsb_wb,at3_bs512_directio.out":

# %% [markdown]
# ## db_bench workload readwhilewriting

# %%
plot.plotFiles([
    'exp_db/dbbench_wwr.out',
    'exp_db/dbbench_wwr,at3_bs4_directio.out',
    'exp_db/dbbench_wwr,at3_bs16_directio.out',
    'exp_db/dbbench_wwr,at3_bs32_directio.out',
    'exp_db/dbbench_wwr,at3_bs64_directio.out',
    'exp_db/dbbench_wwr,at3_bs128_directio.out',
    'exp_db/dbbench_wwr,at3_bs256_directio.out',
    'exp_db/dbbench_wwr,at3_bs512_directio.out',
], options)
# Out:
# ######################################################
# Graphs from file "exp_db/dbbench_wwr.out":
# ######################################################
# Graphs from file "exp_db/dbbench_wwr,at3_bs4_directio.out":
# ######################################################
# Graphs from file "exp_db/dbbench_wwr,at3_bs16_directio.out":
# ######################################################
# Graphs from file "exp_db/dbbench_wwr,at3_bs32_directio.out":
# ######################################################
# Graphs from file "exp_db/dbbench_wwr,at3_bs64_directio.out":
# ######################################################
# Graphs from file "exp_db/dbbench_wwr,at3_bs128_directio.out":
# ######################################################
# Graphs from file "exp_db/dbbench_wwr,at3_bs256_directio.out":
# ######################################################
# Graphs from file "exp_db/dbbench_wwr,at3_bs512_directio.out":
